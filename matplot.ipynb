# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(10,5))
plt.plot([1,2,3], [4,5,6],  ":")
plt.title("Test Chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
plt.figure(figsize=(10,5))
#plt.plot([1,2,3], [4,1,6],  "--", [1,2,3], [3,6,5],  "--", [1,2,3], [2,3,7],  "--")
plt.plot([1,2,3], [4,1,6], [1,2,3], [3,6,5],[1,2,3], [2,3,7])
plt.title("Test Chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot([1,2,3], [4,1,6],  ":")
plt.title("Test Chart")
plt.xlabel("X")
plt.ylabel("Y")

plt.subplot(1,2,2)
plt.plot([1,2,3], [4,1,6],  "--")
plt.title("Test Chart")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %%
plt.subplot(2,1,1)
plt.plot([1,2,3], [4,1,6],  "--")
plt.title("Test Chart")
plt.xlabel("X")
plt.ylabel("Y")

plt.subplot(2,1,2)
plt.plot([1,2,3], [4,1,6],  "--")
plt.title("Test Chart")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %%
plt.figure(figsize=(10,5))
names= ["Tomy", "Rony", "Somu"]
marks= [33,45,36]
plt.bar(names,marks)
plt.title("Test Chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# plt.figure(figsize=(10,5))
# subjects=["pysics", "chemistry", "biology","maths"]
# bmarks= [33,45,36,36]
# gmarks= [3,45,36,36]
# plt.bar(subjects,bmarks)
# plt.title("Test Chart")
# plt.xlabel("X")
# plt.ylabel("Y")
# plt.show()

# %%
plt.figure(figsize=(10,5))
names= ["Tomy", "Rony", "Somu"]
marks= [33,45,36]
exp= [.1,.1, .3]
plt.pie(marks ,labels=names,explode=exp, shadow=True)
plt.title("Test Chart")

plt.show()

# %%
plt.figure(figsize=(10,5))
marks= np.random.randint (0,100,100)
print (marks)
plt.hist(marks,10)
plt.title("Test Chart")

plt.show()
# Out:
# [ 0 79 92 73 62 30 32 24  0 93 77 10 41 14 57 95 79  1 91 23 73 27 96 76
#   8 75 89 72 66 45 39 44 26 66 23 56 18 12 79 91 12 67  4 12 84 63 87 13
#  26 23 42 55 50 13 85 69 61 30 68 21 18 27 12 87 45 53 37  2 94 35 36 20
#  36 43 91 35 95 22 24 32 95 43 26 73 75 13  2 86 41 37  8 77 16 81 59 11
#  99 67 17  6]

# %%
w= [44,55,77,55,88]
h= [140, 160, 168, 150,170]
plt.ylim(20,100)
plt.xlim(100,200)
plt.scatter(h,w)
plt.show()
